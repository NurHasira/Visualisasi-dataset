# %% [markdown]
# <div style="font-family: 'Georgia', 'Garamond', serif;
#             font-size: 22px;
#             background-color: #FADADD;
#             color: #333333;
#             font-weight: bold;
#             text-align: center;
#             padding: 0px 0px;
#             border-radius: 0;
#             width: 100%;
#             letter-spacing: 1px;">
#   Plot Garis
# </div>

# %%
import matplotlib.pyplot as plt

# Data
x = [2, 5, 10, 12, 10, 20]
y = [4, 9, 12, 30, 17, 22]

# Membuat plot garis
plt.plot(x, y)

# Menampilkan plot
plt.show()

# %% [markdown]
# <div style="font-family: 'Georgia', 'Garamond', serif;
#             font-size: 22px;
#             background-color: #FADADD;
#             color: #333333;
#             font-weight: bold;
#             text-align: center;
#             padding: 0px 0px;
#             border-radius: 0;
#             width: 100%;
#             letter-spacing: 1px;">
# Scater Plot
# </div>

# %%
import matplotlib.pyplot as plt

# Data
x = [3, 5, 8, 10, 30]
y = [5, 23, 40, 11, 50]

# Membuat scatter plot
plt.scatter(x, y)
# Menambahkan judul dan label
plt.title("Scatter plot")

# Menampilkan plot
plt.show()

# %% [markdown]
# <div style="font-family: 'Georgia', 'Garamond', serif;
#             font-size: 22px;
#             background-color: #FADADD;
#             color: #333333;
#             font-weight: bold;
#             text-align: center;
#             padding: 0px 0px;
#             border-radius: 0;
#             width: 100%;
#             letter-spacing: 1px;">
#   Bar Plot
# </div>

# %%
import matplotlib.pyplot as plt

# Data
x = ["A", "B", "C", "D", "E"]
y = [100, 70, 50, 20, 40]

# Membuat bar plot
plt.bar(x, y)

# Menambahkan judul dan label
plt.title("Bar Plot")

# Menampilkan plot
plt.show()

# %% [markdown]
# <div style="font-family: 'Georgia', 'Garamond', serif;
#             font-size: 22px;
#             background-color: #FADADD;
#             color: #333333;
#             font-weight: bold;
#             text-align: center;
#             padding: 0px 0px;
#             border-radius: 0;
#             width: 100%;
#             letter-spacing: 1px;">
#   Histogram
# </div>

# %%
import matplotlib.pyplot as plt
#Data
data = [20, 90, 40, 12, 40]
# Membuat histogram
plt.hist(data)
#membuat title
plt.title("Histogram")

# Menampilkan plot
plt.show()

# %% [markdown]
# <div style="font-family: 'Georgia', 'Garamond', serif;
#             font-size: 22px;
#             background-color: #FADADD;
#             color: #333333;
#             font-weight: bold;
#             text-align: center;
#             padding: 0px 0px;
#             border-radius: 0;
#             width: 100%;
#             letter-spacing: 1px;">
#  Pie Chart
# </div>

# %%
import matplotlib.pyplot as plt

# Data
labels = ["E", "F", "G", "H"]
sizes = [20, 47, 35, 50]

# Membuat pie chart
plt.pie(sizes, labels=labels)

# Menampilkan plot
plt.show()

# %% [markdown]
# <div style="font-family: 'Georgia', 'Garamond', serif;
#             font-size: 22px;
#             background-color: #FADADD;
#             color: #333333;
#             font-weight: bold;
#             text-align: center;
#             padding: 0px 0px;
#             border-radius: 0;
#             width: 100%;
#             letter-spacing: 1px;">
#   Menggabungkan Scater Plot dengan Trend Line
# </div>

# %%
# menggabungkan scatter plot dengan tren line
import numpy as np
import matplotlib.pyplot as plt

# Data
x = [3, 6, 8, 10, 6]
y = [5, 7, 9, 12, 15]

# ubah jadi array numpy
x = np.array(x)
y = np.array(y)

# Scatter plot titik-titik yang benar-benar tersebar
plt.scatter(x, y, color='yellow', s=50, label='Data')

# Hitung trend line (regresi linear)
m, b = np.polyfit(x, y, 1)
plt.plot(x, m*x + b, color='blue', label='Trend Line')

plt.title("Scatter Plot dengan Trend Line")
plt.xlabel("Sumbu X")
plt.ylabel("Sumbu Y")
plt.legend()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("Data_Regresi.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   TIME          20 non-null     int64
#  1   Promo(X1)     20 non-null     int64
#  2   Karyawan(X2)  20 non-null     int64
#  3   Jual(Y)       20 non-null     int64
# dtypes: int64(4)
# memory usage: 772.0 bytes

# %% [markdown]
# <div style="font-family: 'Georgia', 'Garamond', serif;
#             font-size: 22px;
#             background-color: #FADADD;
#             color: #333333;
#             font-weight: bold;
#             text-align: center;
#             padding: 0px 0px;
#             border-radius: 0;
#             width: 100%;
#             letter-spacing: 1px;">
#   Box Plot
# </div>

# %%
sns.boxplot(x=df['Promo(X1)'])
# Out:
# <Axes: xlabel='Promo(X1)'>

# %%
sns.boxplot(y=df['Karyawan(X2)'])
# Out:
# <Axes: ylabel='Karyawan(X2)'>

# %%
sns.boxplot(x=df["Promo(X1)"], y=df['Karyawan(X2)'])
# Out:
# <Axes: xlabel='Promo(X1)', ylabel='Karyawan(X2)'>

# %%
sns.boxplot(data=df, x="Jual(Y)", y='Promo(X1)', color="pink")
# Out:
# <Axes: xlabel='Jual(Y)', ylabel='Promo(X1)'>

# %%
custom_pal = {"31": "#FF69B4"}

sns.boxplot(data=df,
            x="Karyawan(X2)", y="Jual(Y)",
            palette="Set2",
            linewidth=0.7,
            width=0.4,
            notch=True,
            fliersize=10,
            flierprops={"marker": "o"})
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_20548\2859002960.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df,
# <Axes: xlabel='Karyawan(X2)', ylabel='Jual(Y)'>

# %%
# Mengatur ukuran frame
plt.figure(figsize=(8, 6))
sns.boxplot(data=df,
            x="Promo(X1)", y='Jual(Y)',
            palette="bright",
            linewidth=0.8,
            width=0.5,
            fliersize=3,
            flierprops={"marker": "o"})
plt.legend(bbox_to_anchor=(1, 0.6), loc=2, borderaxespad=1)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_20548\2849705989.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df,
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_20548\2849705989.py:10: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(bbox_to_anchor=(1, 0.6), loc=2, borderaxespad=1)

# %%
fig, axes = plt.subplots(2, 2, figsize=(8, 6), sharex=False)
sns.boxplot(data=df, x="Jual(Y)", y='Promo(X1)', width=0.6, ax=axes[0, 0])
sns.boxplot(data=df, x="Karyawan(X2)", y='Jual(Y)', width=0.6, ax=axes[0, 1])
sns.boxplot(data=df, x="Promo(X1)", y='Jual(Y)', width=0.6, ax=axes[1, 0])
sns.boxplot(data=df, x="Promo(X1)", y='Karyawan(X2)', width=0.6, ax=axes[1, 1])

 

fig.tight_layout()
